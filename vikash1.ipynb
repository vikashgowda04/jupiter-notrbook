# %%
import pandas as pd

# %%
data=pd.read_csv("Desktop\\vikash.csv")

# %%
data
# Out:
#     Age  Experience  Range Nationality   Go
# 0    40           3      2          UK  yes
# 1    70          13     10       japan   no
# 2    65           9      9         USA   no
# 3    30          22      5       japan  yes
# 4    40          30      8          UK  yes
# 5    20          15      5       japan   no
# 6    50          26      6       india  yes
# 7    54           6      3       india  yes
# 8    43           9      4          UK  yes
# 9    25          19      6         USA   no
# 10   32          10      7         USA   no
# 11   85          12      9         USA  yes
# 12   45           2      5       india   no
# 13   64           5      3       india  yes
# 14   31          12      4          UK  yes
# 15   29          16     10          UK  yes

# %%
import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

df=pd.read_csv('Desktop\\vikash.csv')

d={'india':0, 'USA':1, 'japan':2, 'UK':3}
df['Nationality']=df['Nationality'].map(d)
d={'yes':0, 'no':1}
df['Go']=df['Go'].map(d)

features=['Age','Experience','Range','Nationality']

x=df[features]
y=df['Go']

dtree=DecisionTreeClassifier()
dtree=dtree.fit(x, y)

tree.plot_tree(dtree, feature_names=features)
# Out:
# [Text(0.6666666666666666, 0.9, 'Nationality <= 2.5\ngini = 0.469\nsamples = 16\nvalue = [10, 6]'),
#  Text(0.5, 0.7, 'Experience <= 20.5\ngini = 0.496\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.3333333333333333, 0.5, 'Range <= 4.0\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.16666666666666666, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5, 0.3, 'Age <= 77.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.3333333333333333, 0.1, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.6666666666666666, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6666666666666666, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8333333333333334, 0.7, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]')]
